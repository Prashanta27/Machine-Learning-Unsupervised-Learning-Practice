# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from jinja2.nodes import Output
from sklearn.datasets import make_moons

# %%
x,y = make_moons(n_samples=250,noise = 0.05)

# %%
#df = {"data1":x[:,0],"data2":x[:,1],"Output":y} It is a label data
df = {"data1":x[:,0],"data2":x[:,1]}

# %%
dataset = pd.DataFrame(df)

# %%
dataset
# Out:
#         data1     data2
# 0    0.701293 -0.449862
# 1    1.689664 -0.123111
# 2    1.335655 -0.458551
# 3    0.760329  0.602815
# 4    2.081486  0.520411
# ..        ...       ...
# 245  2.002369  0.224968
# 246  0.973055  0.067277
# 247  1.391223 -0.455724
# 248  0.067712  0.486736
# 249 -0.874720  0.287838
#
# [250 rows x 2 columns]

# %%
sns.scatterplot(x = "data1", y = "data2", data=dataset)
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
db = DBSCAN(eps=0.2, min_samples=5)
dataset["Predict"]=db.fit_predict(dataset)

# %%
sns.scatterplot(x = "data1", y = "data2", data=dataset, hue="Predict")
plt.show()
